# %% [markdown]
# # EDA - Stockholms house prices

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import duckdb as ddb

df = pd.read_csv("data/hemnet_data_clean.csv")
df.head()
# Out:
#    Unnamed: 0             address  asked_price  \
# 0         0.0    Markviksvägen 15    6475000.0
# 1         1.0  Mälarhöjdsvägen 38    9950000.0
# 2         2.0     Häradsvägen 202    5795000.0
# 3         3.0     Hemmansvägen 18   11950000.0
# 4         4.0     Alholmsbacken 8    7950000.0
#
#                                 coordinate  final_price  \
# 0                  [59.371685, 17.8250389]      6950000
# 1                 [59.3008766, 17.9478054]     11300000
# 2  [59.27202322587505, 17.954076342308372]      6200000
# 3   [59.28390406370304, 18.07625832074728]     12700000
# 4                   [59.28134, 17.9009438]      8100000
#
#    pourcentage_difference  land_area   area  \
# 0                     7.0      635.0  117.0
# 1                    14.0      882.0  195.0
# 2                     7.0     1224.0   90.0
# 3                     6.0      542.0  110.0
# 4                     2.0      690.0  157.0
#
# ...

# %%
df.head(30)
# Out:
#     Unnamed: 0                  address  asked_price  \
# 0          0.0         Markviksvägen 15    6475000.0
# 1          1.0       Mälarhöjdsvägen 38    9950000.0
# 2          2.0          Häradsvägen 202    5795000.0
# 3          3.0          Hemmansvägen 18   11950000.0
# 4          4.0          Alholmsbacken 8    7950000.0
# 5          5.0        Herrgårdsvägen 13   14500000.0
# 6          6.0          Skogsslingan 14    5300000.0
# 7          7.0          Brunflogatan 50    7195000.0
# 8          8.0             Knektvägen 8    6395000.0
# 9          9.0           Vinstavägen 14    7875000.0
# 10        10.0             Pliggvägen 2    7500000.0
# 11        11.0   Ivar Hallströms väg 11   12895000.0
# 12        12.0               Bokvägen 1    7950000.0
# 13        13.0              Enebacken 3   13950000.0
# 14        14.0        Nyodlingsvägen 11    9900000.0
# 15        15.0           Vivelvägen 124    6995000.0
# 16        16.0             Enebyvägen 5    8300000.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'address', 'asked_price', 'coordinate', 'final_price',
#        'pourcentage_difference', 'land_area', 'area', 'commune',
#        'price_per_area', 'rooms', 'sale_date', 'supplemental_area'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              500 non-null    float64
#  1   address                 500 non-null    object
#  2   asked_price             500 non-null    float64
#  3   coordinate              500 non-null    object
#  4   final_price             500 non-null    int64
#  5   pourcentage_difference  500 non-null    float64
#  6   land_area               495 non-null    float64
#  7   area                    499 non-null    float64
#  8   commune                 500 non-null    object
#  9   price_per_area          499 non-null    float64
#  10  rooms                   490 non-null    float64
#  11  sale_date               500 non-null    object
#  12  supplemental_area       500 non-null    float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 50.9+ KB

# %%
df['final_price'].head(11)
# Out:
# 0      6950000
# 1     11300000
# 2      6200000
# 3     12700000
# 4      8100000
# 5     16400000
# 6      4910000
# 7      7195000
# 8      6070000
# 9      8500000
# 10     6500000
# Name: final_price, dtype: int64

# %%
df['final_price'].max()
# Out:
# np.int64(31100000)

# %%
df['commune'].head(10)
# Out:
# 0          Hässelby Södra Villastad, Stockholms kommun
# 1           Mälarhöjden - Hägersten, Stockholms kommun
# 2                           Segeltorp, Huddinge kommun
# 3                     Gamla Enskede, Stockholms kommun
# 4                  Skärholmshöjden., Stockholms kommun
# 5                      Enskede Gård, Stockholms kommun
# 6             Johannesdal - Vårberg, Stockholms kommun
# 7    Vällingby - Råcksta Trädgårdsstad, Stockholms ...
# 8                  Trollbäcken/Hanviken, Tyresö kommun
# 9                     Spånga Solhem, Stockholms kommun
# Name: commune, dtype: object

# %%
df[['commune', 'asked_price']]
# Out:
#                                          commune  asked_price
# 0    Hässelby Södra Villastad, Stockholms kommun    6475000.0
# 1     Mälarhöjden - Hägersten, Stockholms kommun    9950000.0
# 2                     Segeltorp, Huddinge kommun    5795000.0
# 3               Gamla Enskede, Stockholms kommun   11950000.0
# 4            Skärholmshöjden., Stockholms kommun    7950000.0
# ..                                           ...          ...
# 495            Älvsjö/Långbro, Stockholms kommun    9500000.0
# 496                     Sätra, Stockholms kommun    7295000.0
# 497                      Skälby, Järfälla kommun    9795000.0
# 498                    Töjnan, Sollentuna kommun   11950000.0
# 499             Gamla Enskede, Stockholms kommun   12495000.0
#
# [500 rows x 2 columns]

# %%
df[['commune', 'final_price']]
# Out:
#                                          commune  final_price
# 0    Hässelby Södra Villastad, Stockholms kommun      6950000
# 1     Mälarhöjden - Hägersten, Stockholms kommun     11300000
# 2                     Segeltorp, Huddinge kommun      6200000
# 3               Gamla Enskede, Stockholms kommun     12700000
# 4            Skärholmshöjden., Stockholms kommun      8100000
# ..                                           ...          ...
# 495            Älvsjö/Långbro, Stockholms kommun     11760000
# 496                     Sätra, Stockholms kommun      7295000
# 497                      Skälby, Järfälla kommun     10200000
# 498                    Töjnan, Sollentuna kommun     13000000
# 499             Gamla Enskede, Stockholms kommun     15000000
#
# [500 rows x 2 columns]

# %%
asked_price = df['asked_price']
asked_price
# Out:
# 0       6475000.0
# 1       9950000.0
# 2       5795000.0
# 3      11950000.0
# 4       7950000.0
#           ...
# 495     9500000.0
# 496     7295000.0
# 497     9795000.0
# 498    11950000.0
# 499    12495000.0
# Name: asked_price, Length: 500, dtype: float64
